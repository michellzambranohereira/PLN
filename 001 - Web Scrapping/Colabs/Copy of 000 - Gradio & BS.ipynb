# %%
pip install gradio -q

# %%
import gradio as gr

# %%
def bienvenida(name):
    return "Hola " + name


demo = gr.Interface(fn=bienvenida, inputs="text", outputs="text")

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://c59faa1b9304c8cde1.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c59faa1b9304c8cde1.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def saludo(nombre, intensidad):
  return "Hola, " + nombre + "!" * int(intensidad)

# %%
demo = gr.Interface(
  fn=saludo,
  inputs=["text", "slider"],
  outputs=["text"],
)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://60abe25f8ba8daf0db.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://60abe25f8ba8daf0db.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def greet(name):
    return "Hello " + name


# We instantiate the Textbox class
textbox = gr.Textbox(label="Type your name here:", placeholder="John Doe", lines=2)

gr.Interface(fn=greet, inputs=textbox, outputs="text").launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://ea461ed8439cdaed5d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ea461ed8439cdaed5d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from bs4 import BeautifulSoup

# %%
html = """
<html>
<head>
  <title>Mi Página de Ejemplo</title>
</head>
<body>
  <h1>Título Principal</h1>
  <p>Este es un párrafo.</p>
  <a href="https://www.ejemplo.com">Enlace a Ejemplo</a>
</body>
</html>
"""

# %%
soup = BeautifulSoup(html, 'html.parser') # Aquí se hace el parsing

print(soup) # Imprime todo el objeto BeautifulSoup
# Out:
# <html>
# <head>
# <title>Mi Página de Ejemplo</title>
# </head>
# <body>
# <h1>Título Principal</h1>
# <p>Este es un párrafo.</p>
# <a href="https://www.ejemplo.com">Enlace a Ejemplo</a>
# </body>
# </html>

# %%
titulo = soup.title
print(titulo)       # Imprime la etiqueta <title>
print(titulo.text)  # Imprime el texto dentro de la etiqueta <title>
# Out:
# <title>Mi Página de Ejemplo</title>
# Mi Página de Ejemplo

# %%
parrafo = soup.p
print(parrafo)      # Imprime la etiqueta <p>
print(parrafo.text) # Imprime el texto dentro de la etiqueta <p>
# Out:
# <p>Este es un párrafo.</p>
# Este es un párrafo.

# %%
html = """
<html><head><title>Mi Página de Ejemplo</title></head><body><h1>Título Principal</h1><p>Este es un párrafo.</p><a href="https://www.ejemplo.com">Enlace a Ejemplo</a></body></html>
"""

soup = BeautifulSoup(html, 'html.parser')

print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Mi Página de Ejemplo
#   </title>
#  </head>
#  <body>
#   <h1>
#    Título Principal
#   </h1>
#   <p>
#    Este es un párrafo.
#   </p>
#   <a href="https://www.ejemplo.com">
#    Enlace a Ejemplo
#   </a>
#  </body>
# </html>

# %%
html = """
<a href="https://www.ejemplo.com" class="enlace-principal">Enlace a Ejemplo</a>
"""

soup = BeautifulSoup(html, 'html.parser')

enlace = soup.a
print(enlace['href'])   # Imprime el valor del atributo 'href'
print(enlace['class'])  # Imprime el valor del atributo 'class'
# Out:
# https://www.ejemplo.com
# ['enlace-principal']
